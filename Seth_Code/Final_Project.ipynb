# %%
using DataFrames
data = readtable("../obs.csv");
# Out:
# INFO: Recompiling stale cache file /Users/scharles/.julia/lib/v0.6/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /Users/scharles/.julia/lib/v0.6/DataFrames.ji for module DataFrames.

# %%
Pkg.add("StatsBase")
# Out:
# INFO: No packages to install, update or remove
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of StatsBase
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
S = 1:288
Sp = 1:288
z1 = zeros(288,288)
for i = 1:length(data[1])
    s = data[1][i]
    sp = data[4][i]
    z1[s+1,sp+1] = z1[s+1,sp+1] + 1
end
heatmap(S,Sp,z1,aspect_ratio=1)
plot!(title="S-Sp Occurrences",label=["Line 1" "Line 2"])
png("S-Sp Occurrences")

# %%
A = 1:63
S = 1:288
z2 = zeros(288,63)
for i = 1:length(data[1])
    s = data[1][i] + 1
    a = data[2][i] + 1
    z2[s,a] = z2[s,a] + 1
end
x = heatmap(A,S,z2,aspect_ratio=1)
plot!(title="State-Action Occurrences",label=["Line 1" "Line 2"])
png("State-Action Occurrences")

# %%
A = 1:63
S = 1:288
z3 = zeros(288,63)
for i = 1:length(data[1])
    s = data[1][i] + 1
    a = data[2][i] + 1
    z3[s,a] = z3[s,a] + data[3][i]
end
x = heatmap(A,S,z3,aspect_ratio=1)
plot!(title="State-Action Total Reward",label=["Line 1" "Line 2"])
png("State-Action Total Reward")

# %%
include("Final_Project.jl")
# Out:
# Random Policy Score: -22.984641
# Random Policy Score: -21.245267
# Random Policy Score: -40.464083
# Random Policy Score: -131.548904
# Random Policy Score: -21.613178
# Random Policy Score: -18.955558
# Random Policy Score: -33.402292
# Random Policy Score: -24.819466
# Random Policy Score: -25.659526
# Random Policy Score: -39.379376
# Random Policy Score: -33.457352
# Random Policy Score: -74.532890
# Random Policy Score: -19.379434
# Random Policy Score: -47.898019
# Random Policy Score: -11.737443
# Random Policy Score: -42.710798
# Random Policy Score: -52.867854
# Random Policy Score: -35.007260
# Random Policy Score: -47.471640
# Random Policy Score: -20.301011
# Random Policy Score: -42.240853
# Random Policy Score: -23.558248
# Random Policy Score: -27.910403
# Random Policy Score: -52.789647
# Random Policy Score: -22.501375
# Random Policy Score: -43.866028
# Random Policy Score: -66.259922
# Random Policy Score: -23.196766
# Random Policy Score: -29.621439
